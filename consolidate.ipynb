# %%
import os
import glob
import pandas as pd

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('data/2020/*'.format(extension))]
print(all_filenames)
# Out:
# ['data/2020\\202001-citibike-tripdata.csv', 'data/2020\\202002-citibike-tripdata.csv']

# %%
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "2019-2020.csv", index=False, encoding='utf-8-sig')

# %%
df= combined_csv.copy()
df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           789  2020-01-01 00:00:55.3900  2020-01-01 00:14:05.1470
# 1          1541  2020-01-01 00:01:08.1020  2020-01-01 00:26:49.1780
# 2          1464  2020-01-01 00:01:42.1400  2020-01-01 00:26:07.0110
# 3           592  2020-01-01 00:01:45.5610  2020-01-01 00:11:38.1550
# 4           702  2020-01-01 00:01:45.7880  2020-01-01 00:13:28.2400
#
#    start station id               start station name  start station latitude  \
# 0               504                  1 Ave & E 16 St               40.732219
# 1              3423  West Drive & Prospect Park West               40.661063
# 2              3687                  E 33 St & 1 Ave               40.743227
# 3               346              Bank St & Hudson St               40.736529
# 4               372        Franklin Ave & Myrtle Ave               40.694546
#
#    start station longitude  end station id           end station name  \
# ...

# %%
def rename_df(df):
    
    
    if (len(df.columns) == 15):
        df.columns = ['Trip Duration (sec)', 'Start Time', 'Stop Time', 'Start Station ID',
       'Start Station Name', 'Start Station Latitude',
       'Start Station Longitude', 'End Station ID', 'End Station Name',
       'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
       'Birth_Year', 'Gender']
    else:
        df.columns = ['Trip Duration (sec)', 'Start Time', 'Stop Time', 'Start Station ID',
       'Start Station Name', 'Start Station Latitude',
       'Start Station Longitude', 'End Station ID', 'End Station Name',
       'End Station Latitude', 'End Station Longitude', 'Bike ID',
       'Localized Value', 'User Type', 'Birth_Year', 'Gender']
        df = df.drop('Localized Value',1)
        
    
    return df

# %%
rename_df(df)
df.head()
# Out:
#    Trip Duration (sec)                Start Time                 Stop Time  \
# 0                  789  2020-01-01 00:00:55.3900  2020-01-01 00:14:05.1470
# 1                 1541  2020-01-01 00:01:08.1020  2020-01-01 00:26:49.1780
# 2                 1464  2020-01-01 00:01:42.1400  2020-01-01 00:26:07.0110
# 3                  592  2020-01-01 00:01:45.5610  2020-01-01 00:11:38.1550
# 4                  702  2020-01-01 00:01:45.7880  2020-01-01 00:13:28.2400
#
#    Start Station ID               Start Station Name  Start Station Latitude  \
# 0               504                  1 Ave & E 16 St               40.732219
# 1              3423  West Drive & Prospect Park West               40.661063
# 2              3687                  E 33 St & 1 Ave               40.743227
# 3               346              Bank St & Hudson St               40.736529
# 4               372        Franklin Ave & Myrtle Ave               40.694546
#
# ...

# %%
# function for cleaning and preparing df
def prepare_df(df):
    
#     drop n/a
    df = df.dropna(how='any').reset_index(drop=True)
    
#     change data types
    df['Birth_Year'] = df.Birth_Year.astype(int)
    df['Start Time'] = pd.to_datetime(df['Start Time'])
    df['Stop Time'] = pd.to_datetime(df['Stop Time'])
    
#     add Age column
    df['Age'] = 2020 - df['Birth_Year']
    
#     exclude ages > 90 years
    df = df[df['Age'] < 90]
    
    return df

# %%
age_df = prepare_df(df)
age_df.head()
# Out:
#    Trip Duration (sec)              Start Time               Stop Time  \
# 0                  789 2020-01-01 00:00:55.390 2020-01-01 00:14:05.147
# 1                 1541 2020-01-01 00:01:08.102 2020-01-01 00:26:49.178
# 2                 1464 2020-01-01 00:01:42.140 2020-01-01 00:26:07.011
# 3                  592 2020-01-01 00:01:45.561 2020-01-01 00:11:38.155
# 4                  702 2020-01-01 00:01:45.788 2020-01-01 00:13:28.240
#
#    Start Station ID               Start Station Name  Start Station Latitude  \
# 0               504                  1 Ave & E 16 St               40.732219
# 1              3423  West Drive & Prospect Park West               40.661063
# 2              3687                  E 33 St & 1 Ave               40.743227
# 3               346              Bank St & Hudson St               40.736529
# 4               372        Franklin Ave & Myrtle Ave               40.694546
#
#    Start Station Longitude  End Station ID           End Station Name  \
# ...

# %%
print(age_df.count())
# Out:
# Trip Duration (sec)        2386091
# Start Time                 2386091
# Stop Time                  2386091
# Start Station ID           2386091
# Start Station Name         2386091
# Start Station Latitude     2386091
# Start Station Longitude    2386091
# End Station ID             2386091
# End Station Name           2386091
# End Station Latitude       2386091
# End Station Longitude      2386091
# Bike ID                    2386091
# User Type                  2386091
# Birth_Year                 2386091
# Gender                     2386091
# Age                        2386091
# dtype: int64

# %%
age_df['Age'].value_counts()
# Out:
# 51    132193
# 30     94683
# 31     94291
# 29     92350
# 28     90458
#        ...
# 87       179
# 88       136
# 86        76
# 16        15
# 89         3
# Name: Age, Length: 74, dtype: int64

# %%
age_df.to_csv('2020_age.csv', encoding='utf-8', index=False)
